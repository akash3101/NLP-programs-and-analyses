# %% [markdown]
# # NLP for Digital markets
#
# ***Akash Gupta (2019DMB02)***
#
# # Language Statistics
#
# Before delving into numerical encodings and transformations of textual data - we present ideas here, that will help us **clean** the textual data and obtain broad overview of the textual characteristics of the **review data**. These broad characteristics are termed as **language statistics** and will essentially give us a flavour of the information and insights trapped in this data. **Note** that in this document, we are exploring two datasets - the review dataset for **HP laptops** and the review dataset for **Lenovo laptops**. Here are some factors we will look at in this regard:
#
# - The **count** of all words in each review dataset - this would give us a sense of **how much content did people write** for each laptop - this is essentially the **vocabulary** that makes up the datasets.
#
# - The **average** length of each review in each dataset. **Length of a review** is denoted by the **number of words used to write that review**. A large average length implies that people have writing detailed responses regarding the product.
#
# - The **count** of all words in each review dataset, without **stopwords**. Stopwords are inconsequential words like - **is, the, of, at, from** - that do not contain any significant information about the textual data.
#
# - The **most frequently occurring words** in each review dataset. This statistic would give us vital insights into the words that predominantly characterize the review dataset.
#
# - The **most rarely occurring words (hapaxes)** in each review dataset. This would give us a sense of what kind of words and characteristics might be stark differentiators between the two datasets.
#
# - We find **collocations** in each dataset. Collocations essentially means - **most frequently occurring bigrams** - where a **bigram** is nothing but a **pair of words**. The output will simply give the most frequently used pair of words that tend to describe each product.
#
# - We find **concordance** in each dataset based on certain **keywords of interest**. This essentially means - **to find the various contexts in which a particular word occurs**. Here we extract the various contexts in which the word **money** have been used.
#
# - We then find **trigrams** which are essentially tuples of **three words**. Here we extract all trigrams that contain the words **money** and **performance** to get an idea of the **sentiment attached to these features**.
#
# - Finally, we find some of the **nouns** used in each dataset. The nouns give us a perspective on - **in what context or about what features** - is the product being discussed.
#
# &nbsp;

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
import re
import random

# %%
df = pd.read_csv('/Users/Akashgupta/Desktop/NEWERFIN/disser/MASTER.csv')

# %%
df2 = pd.read_csv('/Users/Akashgupta/Desktop/NEWERFIN/disser/basic_DELL_data.csv')

# %%
hpdat = df[df['brand'] == 'HP']
#hpdat = hpdat[hpdat['customers'] == 0]
#hpdat = hpdat[hpdat['performance'] == 1]
#hpdat = hpdat[hpdat['appearance_price'] == 1]
hpneg = hpdat[hpdat['LABELS'] == 'pos']
hpneg = hpneg[hpneg['SCORE'] >= 3]
hpneg = hpneg[['REVIEW', 'SCORE', 'LABELS', 'customers']]
hpneg.head()
# Out:
#                                                 REVIEW  SCORE LABELS  \
# 388  writing this review after using the laptop for...      6    pos
# 389  computer technician and have purchased and con...     13    pos
# 390  amazing have never ever thought the ssd can fa...      9    pos
# 391  purchased this laptop 29th october 2019 writin...     19    pos
# 395  the processor fast really good for office work...      3    pos
#
#      customers
# 388          1
# 389          1
# 390          1
# 391          1
# 395          1

# %%
lendat = df[df['brand'] == 'LEN']
lendat = lendat[lendat['customers'] == 0]
lendat = lendat[lendat['performance'] == 1]
lendat = lendat[lendat['appearance_price'] == 1]
lenneg = lendat[lendat['LABELS'] == 'neg']
lenneg = lenneg[['REVIEW', 'SCORE', 'LABELS', 'customers']]
lenneg.head()
# Out:
#                                                 REVIEW  SCORE LABELS  \
# 757  received s145 with warranty months remaining w...     -2    neg
# 758  telling you this laptop not worth any your mon...     -1    neg
# 762  never buy this laptop outright pathetic just d...     -6    neg
# 763  using for last days best for office document b...      0    neg
# 764  excellent product this price point only batter...     -2    neg
#
#      customers
# 757          0
# 758          0
# 762          0
# 763          0
# 764          0

# %%
print("average negative intensity for lenovo customer: ", np.abs(lenneg['SCORE']).mean())
print(len(lenneg['REVIEW']))
# Out:
# average negative intensity for lenovo customer:  1.6779661016949152
# 59

# %%
print("average negative intensity for hp customer: ", np.abs(hpneg['SCORE']).mean())
print(len(hpneg['REVIEW']))
# Out:
# average negative intensity for hp customer:  4.967213114754099
# 61

# %% [markdown]
# &nbsp;
#
# ## The implementation program
#
# Below is essentially a custom made program that encapsulates the above mentioned functions. This program has been created such that one can simply pass the data to it - and it will output the desired language statistics.
#
# &nbsp;

# %%
class L_stats(object):
    def __init__(self, raw, col_name):
        self.raw = raw
        self.col_name = col_name
        
    def tokenized(self):
        tokens = []
        for review in self.raw[self.col_name]:
            tokens.append([w.lower() for w in nltk.word_tokenize(review) if len(w)>2])
        return tokens
    
    def vocab(self):
        voc = []
        for review in self.raw[self.col_name]:
            voc += [w.lower() for w in nltk.word_tokenize(review) if len(w)>2]
        return voc
    
    def tokenized_uni(self):
        tokens = []
        for review in self.raw[self.col_name]:
            tokens.append(list(set([w.lower() for w in nltk.word_tokenize(review) if len(w)>2])))
        return tokens
    
    def vocab_uni(self):
        voc = []
        for review in self.raw[self.col_name]:
            voc += [w.lower() for w in nltk.word_tokenize(review) if len(w)>2]
        return list(set(voc))
    
    def avg_word_count(self):
        avg = 0
        v = self.tokenized()
        for review in v:
            avg += (len(review)/len(v))
        avg = np.round(avg, 2)
        return avg
    
    def tokenized_no_stops(self):
        DF = []
        c = self.tokenized()
        for r in c:
            DF.append([w.lower() for w in r if w.lower() not in stopwords.words('english')])
        return DF
    
    def vocab_no_stops(self):
        v = self.vocab()
        d = [w.lower() for w in v if w.lower() not in stopwords.words('english')]
        return d
    
    def count_stats(self):
        print("Total number of words in all reviews: ", len(self.vocab()))
        print()
        print("Average number of words in each review: ", self.avg_word_count())
        print()
        print("Total number of words in all reviews without stopwords", len(self.vocab_no_stops()))
         
    def frequencies(self):
        print("Top 60 most frequently occurring words in the dataset, along with their count:")
        print()
        var2 = nltk.FreqDist(self.vocab()).most_common(60)
        for i in range(60):
            print(var2[i])
    
    def frequencies_stop(self):
        print("Top 30 most frequently occurring words in the data without stops, along with their count:")
        print()
        var = nltk.FreqDist(self.vocab_no_stops()).most_common(30)
        for i in range(30):
            print(var[i])
    
    def hapaxes(self):
        print("Top 60 most rare words that occur only once in the review dataset:")
        print()
        vvv = self.vocab()
        var3 = nltk.FreqDist(vvv).hapaxes()
        for i in range(60):
            print(var3[i])
            
    def collocation(self):
        print("Most frequent bigrams (pairs of words): ")
        print()
        v4 = self.vocab()
        t = nltk.Text(v4)
        print(t.collocations())
        #print()
        #dft = self.tokenized()
        #for r in dft:
            #t = nltk.Text(r)
            #if t.collocations() != None:
                #print(t.collocations())
                
    def concord(self, word):
        vs = self.vocab()
        tt = nltk.Text(vs)
        print(tt.concordance(word))
        
    def trigrams(self, word):
        vv = self.vocab()
        t6 = nltk.Text(vv)
        print(t6.findall(r'<.*> <.*> <{}>'.format(word)))
        
    def nouns(self):
        vvs = self.vocab()
        nouns = [w for (w, n) in nltk.pos_tag(vvs) if n in ['NN', 'NNP']]
        return nouns

# %%
z = pd.read_csv('/Users/Akashgupta/Desktop/NEWERFIN/disser/zero.csv')
o = pd.read_csv('/Users/Akashgupta/Desktop/NEWERFIN/disser/one.csv')
t = pd.read_csv('/Users/Akashgupta/Desktop/NEWERFIN/disser/two.csv')

# %%
Z = L_stats(z, 'REVIEW')
O = L_stats(o, 'REVIEW')
T = L_stats(t, 'REVIEW')

# %%
dfz = Z.tokenized()
dfo = O.tokenized()
dft = T.tokenized()

# %%
Lenovo = L_stats(lenneg, 'REVIEW')
HP = L_stats(hpneg, 'REVIEW')

# %%
df_l = Lenovo.tokenized()
df_h = HP.tokenized()

# %%
V_l = Lenovo.vocab()
V_h = HP.vocab()

# %% [markdown]
# &nbsp;
#
# ## Count statistics
#
# The count statistics are given below.
#
# - We see that **Lenovo** reviews are on average, longer in length and people have written longer reviews for it as compared to reviews on **HP**.
#
# &nbsp;

# %%
Z.count_stats()
# Out:
# Total number of words in all reviews:  44671
#
# Average number of words in each review:  60.2
#
# Total number of words in all reviews without stopwords 29907

# %%
O.count_stats()
# Out:
# Total number of words in all reviews:  11271
#
# Average number of words in each review:  20.16
#
# Total number of words in all reviews without stopwords 8525

# %%
T.count_stats()
# Out:
# Total number of words in all reviews:  1713
#
# Average number of words in each review:  12.98
#
# Total number of words in all reviews without stopwords 1254

# %% [markdown]
# &nbsp;
#
# ## Frequent words
#
# - Some of high frequency characteristic words for **Lenovo** are - **good, battery, slow, price, money, performance, poor, bad, processor**.
#
# - Some of the high frequency characteristic words for **HP** are - **good, performance, battery, fast, light, weight, display, SSD**.
#
# &nbsp;

# %%
Z.frequencies_stop()
# Out:
# Top 30 most frequently occurring words in the data without stops, along with their count:
#
# ('laptop', 872)
# ('good', 326)
# ('product', 315)
# ("n't", 260)
# ('apple', 238)
# ('battery', 226)
# ('buy', 215)
# ('amazon', 206)
# ('one', 198)
# ('macbook', 171)
# ('like', 169)
# ('dell', 166)
# ('use', 164)
# ('windows', 153)
# ('...', 152)
# ('get', 142)
# ('mac', 142)
# ('even', 141)
# ('performance', 139)
# ('also', 138)
# ('time', 137)
# ('price', 136)
# ('bought', 135)
# ('service', 133)
# ('quality', 132)
# ('working', 128)
# ('screen', 123)
# ('display', 120)
# ('using', 119)
# ('better', 117)

# %%
O.frequencies_stop()
# Out:
# Top 30 most frequently occurring words in the data without stops, along with their count:
#
# ('good', 376)
# ('battery', 215)
# ('quality', 179)
# ('laptop', 176)
# ('performance', 151)
# ('product', 121)
# ('light', 99)
# ('life', 82)
# ('...', 80)
# ('display', 77)
# ('screen', 72)
# ('fast', 71)
# ('also', 66)
# ('weight', 65)
# ('slow', 65)
# ('use', 64)
# ('backup', 63)
# ('poor', 63)
# ('sound', 61)
# ('best', 58)
# ('like', 57)
# ('design', 54)
# ('great', 50)
# ('awesome', 48)
# ('overall', 48)
# ('price', 46)
# ('office', 44)
# ('nice', 40)
# ('processor', 40)
# ('money', 39)

# %%
T.frequencies_stop()
# Out:
# Top 30 most frequently occurring words in the data without stops, along with their count:
#
# ('money', 79)
# ('price', 72)
# ('product', 72)
# ('value', 57)
# ('good', 49)
# ('laptop', 42)
# ('best', 37)
# ('range', 31)
# ('nice', 26)
# ('great', 17)
# ('waste', 16)
# ('performance', 15)
# ('battery', 14)
# ('excellent', 12)
# ('...', 12)
# ('buy', 11)
# ("n't", 10)
# ('worth', 9)
# ('really', 8)
# ('one', 8)
# ('also', 7)
# ('awesome', 7)
# ('high', 7)
# ('quality', 6)
# ('like', 6)
# ('design', 6)
# ('weight', 6)
# ('screen', 5)
# ('display', 5)
# ('decent', 5)

# %% [markdown]
# &nbsp;
#
# ## Common words correlated with NOT
#
# - In **Lenovo** reviews the most correlated words with the word **NOT** are - **good, working, buy, worth, recommend, functioning** - indicating negative sentiments with respect to the said features.
#
# - In **HP** reviews the most correlated words with the word **NOT** are - **working, worth, charging, suitable**.
#
# &nbsp;

# %%
bigram_L = nltk.bigrams(Z.vocab())
cfd2 = nltk.ConditionalFreqDist(list(bigram_L))
cfd2['not'].most_common(20)
# Out:
# [('working', 31),
#  ('for', 20),
#  ('buy', 19),
#  ('good', 16),
#  ('even', 15),
#  ('that', 13),
#  ('worth', 12),
#  ('the', 10),
#  ('sure', 10),
#  ('recommend', 8),
#  ('getting', 8),
#  ('find', 8),
#  ('work', 7),
#  ('able', 7),
#  ('recommended', 7),
#  ('all', 7),
#  ('available', 6),
#  ('very', 6),
#  ('charging', 6),
#  ('installed', 6)]

# %%
bigram_H = nltk.bigrams(O.vocab())
cfd3 = nltk.ConditionalFreqDist(list(bigram_H))
cfd3['not'].most_common(20)
# Out:
# [('good', 28),
#  ('for', 9),
#  ('that', 7),
#  ('worth', 7),
#  ('recommended', 5),
#  ('bad', 5),
#  ('upto', 4),
#  ('very', 4),
#  ('the', 4),
#  ('buy', 4),
#  ('sure', 3),
#  ('functioning', 3),
#  ('all', 3),
#  ('used', 3),
#  ('have', 3),
#  ('quite', 3),
#  ('even', 3),
#  ('enough', 3),
#  ('available', 2),
#  ('much', 2)]

# %%
bigram_H4 = nltk.bigrams(T.vocab())
cfd34 = nltk.ConditionalFreqDist(list(bigram_H4))
cfd34['not'].most_common(20)
# Out:
# [('amazon', 1),
#  ('good', 1),
#  ('bad', 1),
#  ('available', 1),
#  ('value', 1),
#  ('refundable', 1),
#  ('buy', 1),
#  ('anti-glare', 1),
#  ('excellent', 1),
#  ('expected', 1),
#  ('made', 1),
#  ('for', 1)]

# %% [markdown]
# &nbsp;
#
# ## Hapaxes
#
# - Some of the rare characteristic words for **Lenovo** are - **noise, novice, frustrated, scrap, trackpad**.
#
# - Some of the rare characteristic words for **HP** are - **surprise, useless, multitasking, bandwidth**.
#
# &nbsp;

# %%
Z.hapaxes()
# Out:
# Top 60 most rare words that occur only once in the review dataset:
#
# 4~5
# permits
# ish
# rainy
# season
# os+dells
# utilities
# .gb
# hynix
# 3200
# latency
# nos
# reserved
# 80~90gb
# partition
# resistance
# inserting
# fear
# breaking
# encryption
# 74000rs
# damages
# warnings
# shipping
# tasking
# maintain
# temperature
# farcry
# assasins
# creeed
# entry
# preffer
# limitted
# unsealed
# surity
# evenafter
# assurance
# havent
# speakers-here
# vist
# bilaspur
# c.g
# techies
# faqs
# tensed
# fail
# occurred
# predecessor
# 3590
# mesh
# gtx
# pcie
# lanes
# premiere
# filter
# demanding
# megabytes
# 2.0
# mbps
# hdmi,1

# %%
O.hapaxes()
# Out:
# Top 60 most rare words that occur only once in the review dataset:
#
# sealed
# loose
# already
# covered
# 65k+
# layout
# neatness
# website
# know
# why
# seven
# reduced
# paid
# 64k
# change
# green
# increasing
# gave
# proper
# others
# adequately
# somewhat
# similar
# fingerpint
# supply
# delicate
# 2hr
# sealer
# devlopment
# sell
# digree
# celcius
# winter
# fine.but
# website.however
# assistance
# immediately
# cause
# solution
# ordered
# nov
# message
# immediate
# power-off/shutdown
# lightning
# data
# 11th
# needing
# mechanism
# accidently
# clicked
# 60hz
# refresh
# shift
# good.graphics
# .overall
# powered
# good🔥
# 130w
# type-c

# %% [markdown]
# &nbsp;
#
# ## Collocations
#
# - Some of the most common bigrams for **Lenovo** are - **battery life, battery backup, light weight, online classes, waste money, camera quality, price range, build quality**.
#
# - Some of the most common bigrams for **HP** are - **light weight, build quality, watching movies, microsoft account, made china, customer care**.
#
# &nbsp;

# %%
Z.collocation()
# Out:
# Most frequent bigrams (pairs of words):
#
# battery life; macbook air; service center; light weight; stopped
# working; build quality; battery backup; service centre; logic board;
# customer care; macbook pro; android studio; price range; video
# editing; 10th gen; finger print; sound quality; mother board;
# microsoft office; online classes
# None

# %%
O.collocation()
# Out:
# Most frequent bigrams (pairs of words):
#
# light weight; battery life; battery backup; build quality; sound
# quality; screen quality; camera quality; macbook air; heating issues;
# online classes; worth buying; waste money; hard drive; backlit
# keyboard; also good; dont buy; fan sound; built quality; heating
# issue; 4gb ram
# None

# %%
T.collocation()
# Out:
# Most frequent bigrams (pairs of words):
#
# price range; waste money; light weight; nice product; online classes;
# n't buy; battery life; build quality; great product; excellent
# product; battery backup; good product; price point; low range; money
# best; money ...; definitely value; awesome product; price awesome;
# best laptop
# None

# %% [markdown]
# &nbsp;
#
# ## Concordance
#
# - For **Lenovo** it seems like quite a lot of contexts around **money** involves negative words like **waste** and **not worth** even though some positive words are also there.
#
# - For **HP** it seems like a lot of contexts around **money** involves positive words like **value for**.
#
# &nbsp;

# %%
Lenovo.concord('screen')
# Out:
# Displaying 15 of 15 matches:
# ptop 've ever seen even refresh the screen 'll take more than minutes just ref
# ndows best product this price range screen quality good but battery lasts only
# essor very slow battery backup poor screen quality not good the processor way
# t that good too slow sometimes also screen quality not great but battery life
# anged not good the battery life and screen the very pathetic very poor laptop
# ay led but the quality not like led screen also installed only msoffice and ad
# prints wer clearly visible like the screen size strongly recommend not buying
# eating dead slow processor horrible screen laptop design was very good.but sou
# king for good battery life also the screen sooo dim the charger not connected
# harging its very slower performance screen quality very poor battery hardly gi
# eend the key attached the photo the screen slowest ever freezing frequently ju
# ing and laptop back panel also heat screen resolution very poor showing error
# uality good.processor also slow the screen quality very poor very disappointed
# ery disappointed from the first day screen light was blinking very slow operat
#  and honor the build filmsy and the screen has very poor brightness show good
# None

# %%
HP.concord('ssd')
# Out:
# Displaying 23 of 23 matches:
# he laptop boots just second very fast ssd the shutdown also takes just second t
# his laptop super fast because its m.2 ssd clients with 3rd and 4th generation c
# ition word excel one note has 250 m.2 ssd storage blazing fast single slot ram
# s amazing have never ever thought the ssd can fast that the windows will boot j
# ws office and powerful processor with ssd this segment upto ₹28,000 purchased t
# owerpoint and basic editing tasks due ssd works like charm pros ssd makes prett
# g tasks due ssd works like charm pros ssd makes pretty fast with 5-7 seconds bo
#  save money and put that more ram and ssd also has only single ram slot you wou
# mory please remember dual channel ram ssd the key smooth performance ssd alone
# el ram ssd the key smooth performance ssd alone will only make startup and shut
# s intel icore5 10gen with ram and 512 ssd the system having high end configurat
#  office utility for programming being ssd device quite fast than hdd machines k
# l laptop adding some more ram 8gb and ssd 240 and that whole setup costs 60k st
# eed good performance provided ram and ssd and are ready compromise cons mention
# bought fast expected with ram and 512 ssd build quality not the best could have
# d quite happy with performance effect ssd bootup time less than seconds using a
# he laptop best this range you get 512 ssd with ram which makes the performance
#  ssds are must also bought 240gb sata ssd worth will move the windows ssd once
#  sata ssd worth will move the windows ssd once receive but that will ruin the w
# hat not something you want please for ssd alternative like this laptop here oth
# cludes intel core processor and 512gb ssd which makes laptop 20x faster than hd
# this review month since purchased the ssd make this laptop faster and the perfo
#  laptop windows laptop then 10th only ssd available fast compact and light weig
# None

# %% [markdown]
# &nbsp;
#
# ## Trigrams
#
# - Some common trigrams for **Lenovo** around **money** are - **laptop waste money, value for money, dont waste money, worth the money, buying waste money, awesome value money, hard earn money**.
#
# - Some common trigrams for **Lenovo** around **performance** are - **expect great performance, such poor performance, very slow performance, fantastic best performance**.
#
# - Some common trigrams for **HP** around **money** are - **value for money spend some money, absolute waste money, worth for money**.
#
# - Some common trigrams for **HP** around **performance** are - **job poor performance, good battery performance, much great performance, slow rubbish performance**.
#
# &nbsp;

# %%
print(Lenovo.trigrams('product'))
print()
# Out:
# highspeed broadband product; worst possible product; this junk
# product; via online product; open worst product
# None
# None

# %%
print(HP.trigrams('ssd'))
print()
# Out:
# very fast ssd; its m.2 ssd; 250 m.2 ssd; thought the ssd; processor
# with ssd; tasks due ssd; charm pros ssd; ram and ssd; channel ram ssd;
# smooth performance ssd; and 512 ssd; programming being ssd; 8gb and
# ssd; ram and ssd; and 512 ssd; performance effect ssd; get 512 ssd;
# 240gb sata ssd; the windows ssd; please for ssd; and 512gb ssd;
# purchased the ssd; 10th only ssd
# None
# None

# %% [markdown]
# &nbsp;
#
# ## Nouns
#
# - Some associated nouns with **Lenovo** are - **display, processor, RAM, plastic, battery**.
#
# - Some associated nouns with **HP** are - **light, battery, office, booting, SSD**.
#
# &nbsp;

# %%
Lenovo.nouns()[:30]
# Out:
# ['lenovo',
#  'care',
#  'action',
#  'period',
#  'ddr4',
#  'care',
#  'advice',
#  'word',
#  'vice',
#  'city',
#  'purchase',
#  'malfunction',
#  'start',
#  'operation',
#  'communication',
#  'claim',
#  'replacement',
#  'warranty',
#  'situation',
#  'request',
#  'visit',
#  'september',
#  'keypad',
#  'replacement',
#  'malfunction',
#  'issue',
#  'service',
#  'request',
#  'september',
#  'response']

# %%
HP.nouns()[:30]
# Out:
# ['review',
#  'laptop',
#  'month',
#  'office',
#  'account',
#  'account',
#  'shutdown',
#  'time',
#  'processing',
#  'price',
#  'work',
#  'hour',
#  'charge',
#  'autocad',
#  'performance',
#  'one',
#  'computer',
#  'technician',
#  'amazon',
#  'setup',
#  'super',
#  'm.2',
#  'ssd',
#  'generation',
#  'core',
#  'difference',
#  'year',
#  'laptops',
#  'cache',
#  'excel']

# %%
df2.columns
# Out:
# Index(['DELL'], dtype='object')

# %%
for i in range(len(df2['DELL'])):
    print(str(i+1) + "--> " + df2['DELL'][i])
    print()
# Out:
# 1--> Using it for last 4~5 days. This is my 4th laptop. Main usage is for development and when time permits little bit of gaming.
#
# What I like.
# 1. Good processor. Provide balanced performance.
# 2. Though 100% plastic body shell, its overall build quality is good.
# 3. Mid range gpu enough for all purpose usage except for high end gaming.
# 4. Okay ish sound nothing to complain about.
# 5. Screen quality too is acceptable at this price point.
# 6. Though not used it, the laptop provides finger print scanner.
# 7. So far no issues with cooling but it's too early to comment as overall ambience is on a cooler side due to rainy season.
#
# What I didn't like.
# 1. Only 8 GB ram. 4 GB is consumed by os+dells own utilities. In need to upgrade to 16 .GB.
# 2. Hynix DDR4 3200 ram module. Overall okay with performance point of view but should have put better ram with better Latency nos.
# 3. Samsung 256 GB ssd. Dell has reserved about 80~90gb for recovery partition. With os, Dell's own software with MS office and other basic software installed, 50% storage is consumed. Would have liked a 500 GB ssd at least as an option.
# 4. 1TB HDD is super slow. Replaced it with a 500gb sata ssd.
# 5. Touch pad buttons are heavy, stopped using the touch pad on first day itself.
# 6. USB ports are hard to use. Very small gap on top side which create high resistance while inserting a device. Fear of breaking the port.
# 7. Os by default uses bitlocker. Initially I was not happy with the hard disk (ssd) performance. But once I turned the encryption off, the performance improved a lot. Suggest turning it off if one don't need the added security.
#
# 2--> I got a detective laptop .It didn't turn on and I had the worst customer support ever from both dell and Amazon.They were of no help I regret buying this laptop…
#
# 3--> guys , i bought this dell g3 3500 laptop a week ago from amazon for 74000rs , which is a bit overpriced . the packaging was already damaged and opened when i got it but i couldnt find any physical damages on the laptop. i have been using it for the last few days,, the laptop just shut down without any warnings just like that . this happened a few times. and the finger print scanner was also found defective within a few days it couldnt recognise my finger after i turn it on from sleep mode. i also happened to hear some popping sound from the speakers. these were the problems that i encountered .. i think that these were the problems caused by some hard ware damage caused during shipping or something however i have initiated a replacement for it.
#
# now for the good parts apart from these issues i think that this is a pretty good laptop for normal use, some multi tasking and some normal gaming. i have to say this has got really good speakers, the sound quality was ok but it was quite loud , we cant find that in most of the laptops now in the market. the keyboard was also good . screen is also alright for normal use and casual gaming . but i would suggest getting a laptop with higher refresh rate if you are a hard core gamer. i got really good battery backup during normal use. that also is rare in the case of gaming laptops. you wont get even an hour of backup during game play, you cant expect that from a gaming laptop. the laptop does not heat that much as compared to many other gaming laptops the game boost button helps maintain the temperature and gives much good performance. gaming was also pretty good considering the price . i tried farcry 4 , gta 5 , assasins creeed . the gaming was alright.. dell managed to keep the design of the laptop simple and elegant . it is not that much heavy . you also get good softwares from dell like the alienware command center and my dell application which was quite helpful.
#
# and for some more of the bad parts the hard drive is really slow it took really long to load even pictures from the hard drive. i suggest you upgrade the storage with some ssd.. the webcam is also not that good .
#
# considering the fact that this is a entry level budget gaming laptop this is pretty good for those who preffer dell laptops and you are limitted with this budget i would definitely suggest you this laptop. you can go for it..
#
# 4--> After using it for about a month..
# Good specs and performance.
# screen looks dull at first but after disabling eco screen from boot menu looks great.
# price is somewhat high than others but with the quality you get it is worth it.
# sound is awesome with Alienware controls , keyboard is nice, USB ports are tight at first but works nice after 2-3 days.. only downgrad here is battery performance but guys its gaming system so it can be neglected.
# tried with many games, runs smoother, you need to disable power saving option to get more then 30 fps.. its in nvidia game experince control.
# Delivery here was late but very happy with what i got. Thanks to Amazon and delivey agents
#
# 5--> Using this product for 10 days,no issues at all. The laptop boot time was very fast due to SSD. Display was too good even though 60HZ refresh rate. Battery lasts for 3 hrs on high end processing .but for games using Game shift key hardly lasts an hour. for normal use battery lasts for 5-6 hrs. Fingerprint sensor is also good.Graphics also very good for game no lags at all .Overall good product and also value for money for these specifications.
#
# 6--> Good product
# Looks good and good performance
#
# 7--> Dell has always been a trusted company. So Dell G3 is not an exception.
#
# Pros:
# 1. Very sleek design, you will always get a premium feel while using the laptop.
# 2. Lightning fast boot.
# 3. Awesome display with very thin bezel.
# 4. Just press G key (F7) to toggle fan speed.
# 5. Touchpad is super responsive, so as the blue backlit keyboard.
# 6. Great battery life, I have played FC4 for 4 hrs continuously, battery came down to 30% from full.
# 7. Pre equipped with original windows 10 home single language and ms office 2019 trial version, all latest drivers are pre installed.
# 8. Air vent and fans are very well placed for great heat reduction.
#
# Cons:
# 1. Original Dell backpack is not given with it which we normally get for free in case we purchase laptop from an offline store, always. This is very disappointing.
#
# Performance wise no problem found till date as I am using this laptop only for 6 days.
#
# Those who wants a decent laptop with gaming performance but not very colorful design within a great budget, they may go for it.
#
# It looks like a sports car for me and a beast performer. Thanks Amazon team for the great deal.
#
# 8--> This laptop came on thursday and now today is Sunday which is the day I am writing this review. Today (16-7-20) I was watching on YouTube with this laptop and this laptop suddenly was switched off it's battery was also 98%. But I don't know why it got switched off. Very bad laptop
#
# 9--> Please don't get cheated. Wrong information has been given, description (along with the heading) says that the laptop includes MS Office but the office is only installed, it's not activated neither you get any activation key or any other way to activate rather than paying extra Rs.5000.
# There is also a lag of around 4-5 seconds in webcam during recording mode.
# Please do not try to cheat the buyers by giving wrong information.
#
# 10--> Overall products was good but when I was received dell box was unsealed. Battery drained within 2 hours during normal usage. I had purchased Dell because of battery backup, it's shows minimum 5-6 hrs during normal usage but actually within 2 hours battery drained. Also during purchase in specifications, products country of origin shows Made In India but actually I received completely Made In China. This thing made me very upset. I had complained to Amazon customer care, they had given surity to give made in India laptop.
#
# When I received new laptop after replacement, same made in China laptop received evenafter assurance of Amazon customer care. Again I had complained country of origin issue. Still problem not resolved.
#
# Can anybody tell me, this laptop is made in India or china??
#
# 11--> Not value for money product.
# Product is Nice. But 1650 at this price range. Seriously. Other brands provide 1660ti on this price range.
# Who cares about 10gen or 9gen.
# Graphic card is most important thing in a Gamer laptop.
#
# 12--> Its good and works as told. Not a high end gaming laptop but its great for all the office work and also kids work. It also does play games. I love it. The only thing I was worried is the weight. Its heavy. If you want to carry it around with one hand you will feel your hand hurting ...else its cool.... good one. If it was a little cheap it would have been better.
#
# 13--> Well, I can proudly say that I have bought the best laptop of all in this segment, just blindly go for it. Why I am saying this is because-
# 1. Hardware is so good like it's so sturdy and looks like it can last long as 5,6 years easily.
# 2. Lithining fast speed with the SSD and 10th gen i5 processor.
# 3. Best Dell service support.
# 4. Amazon is a very reliable e-commerce provider, got laptop in just 2 days.
# 5. Battery life of this machine is also at its best easily getting 4-5 hours
# 6. G button and alien command center when the laptop gets heated I just press it and the system takes care of itself.
#
# con-
# 1. Only one that you don't get good warranty extension offers from dell, its costly.
# 2. Buy the laptop when the price drops, I got it in 68k with a coupon applied on Amazon.
#
# Finally I can say that Dell is Dell and the branding matters, don't go for cheaper ones like acer, asus or lenovo, you will regret it. Go for a one-time big purchase and get this laptop.
#
# 14--> First I got a laptop and opened it and after one day I found a problem in it it had a bluetooth problem so I raised a complain for a replacement. Then I got a new one after 3days and the 2nd laptop had a software issue. I am so disappointed with it I got a used one 2and time so I claimed for a refund today I got my refund so iam writing this ..so check and buy laptop a product especially when it is an electronic one.
#
# 15--> I had some doubts about product expectations and reading the reviews before buying. As I am very much reliable on dell products and their durability I had no issues with the laptop. I have two reasons to decide on this laptop 1st gaming/multitasking and programming and 2nd the configuration. if you are using your old laptop with the old configuration you will find it hard to use at first after 1 day of full diagnostics and setting up my configuration is easy to adjust. Battery life is excellent and up to 6-8hrs in normal mode and when enabled to g force it goes till 4 hrs as its gaming turn on. fingerprint sign in as well as display colors are excellent. mouse sensitivity at first I had a problem because it's too sensitive but after that, I got used to it. startup time is less than 10 sec which was amazing and no errors of update failure till now. Nvidia graphics experience for me was excellent as it was my first time. the Alienware monitoring system lets you control your pc environment as well as it learns from the user daily time spent, I had no heating problem fan speed was good. Dell software updates for drivers are keeping my laptop up to date. I would suggest to those who are looking for a new laptop go for it as it looks good as well as it runs better.
#
# 16--> This laptop is good in almost all terms(Though I am not a gamer and havent used this for gaming)..\
# Good build quality (Though plastic)
# Very good display
# battery back up on normal usage is around 6 hours(No heavy apps or videos) just browsing
# Laptop feels a little heavier(As it is a gaming laptop)
# Speakers-Here comes the main problem,There is an issue with the speakers as they are giving distortion sound...But after technician vist amazon replaced the laptop to my bad luck even the replacement had the same speaker issue..I believe thats due to form factor or the speaker placement...Will be going for refund as I really cannot waste time anymore
#
# 17--> This thing is heavy, but manageable, has most of the drivers up-to-date, easy setup, solid minimalist design, no crazy RGB , the heat vents remind me of those Porsche cars
# You can take it to office for any presentation and nobody will know it's a gaming laptop
#
# 18--> Tried different cables but doesnt go in the 2 USB ports, works with the 3rd port. It was a gift for my brother in law, checked yesterday as it was his birthday and couldnt replace as the period ended
#
# 19--> Battery backup is awesome ❤️ and gaming with alienware is over powered & too good🔥 Fast charging with 130w charger.
# We need Type-c port in dell laptop
#
# 20--> Good pc but little bit expensive as compared to asus and hp but dell overall experience and durability is much better than asus may be only hp can give thought competition.dell's coutemer care is great and very quick. One of the best service. Good bulid quality and the greatest one the cooling system of this laptop is one the top due to which the r damage risk of your laptop parts is almost 0 . GO FOR IT IF YOU WISH TO HAVE LAPTOP FOR LONG TERMS ( ABOVE 5 YEARS )
#
# 21--> Amazing buy. I have been using it for a month n there r no problems what so ever with this laptop. It is running absolutely perfectly.
# Pro's:
# 1. Battery backup is excellent. I can play cyberpunk game for 3 hrs. By that u can understand the battery performance.
# 2. Boot speed is less than 2 seconds.
# 3. Finger print scanner.
# 4. No issues with cooling.
#
# Con's are none as of now.
#
# Worth the amount I paid for. I would definitely recommend to buy this product if u could afford it.
#
# 22--> Packing was not good....because the outer cover was all wet and cardboard was literally dripping water...thanks to dell it provides with a waterproof cover in all parts that are inside the box...
# Will review laptop soon…
#
# 23--> This is my second gaming laptop. I found overall configuration good . Laptop have 2 fans and multiple exhaust outlets. Keyboard are bit stiff but overall laptop is good.
#
# 24--> Awesome product. Superfast boot. Worth buying
#
# 25--> The amazon is very insensitive towards the customer purchase. There was no physical invoice copy sent to the customer. The online copy of invoice doesn't have serial number. The request was made to the amazon for innumerable times but helpless. Laptop is performing good. But the seller attitude is pathetic.
#
# 26--> Product firstly when come then looks little bad on start but when it updated , looks great . Awesome speaker, camera, keyboard. Finally value for money . Also company was dell but it is made in china 😂 so please compromise as made in india laptop will come in 2030.
#
# 27--> It's almost been a month, I bought it from Amazon.in, the laptop is worth for the money.
# Battery life is very good and works according to the Power mode we select, Nvidia card accelerates the gaming experience, Analytics guys will love to work on this as the I5 10th Gen is super fast.
#
# 28--> Laptop is awesome. I liked it.. Only the thing is firstly you have to set lid open screen off that was little bit scary as i thought my battery was draining faster. Later it was rectified. Rather than that its awesome works smooth. You have to restore your refresh rate to 120 hz.
#
# 29--> Better is very bad because they say it would be use 10 hours in stand by and average plz don't buy this if you search a long life battery of laptop. They say wrong I saw what they say about battery and after I think that I may buy this but now I feel soo bad for purchasing this product
#
# 30--> Hi, anyone who is looking for a budget laptop, whether is simple task or hardcore gaming, this would satisfy your need. Just go for it and buy during offer period.
#
# 31--> Nice laptop
#
# 32--> Really nice product worth the price excellent battery life and display. The ac adaptor is also nice. I liked its fingerprint sensor which can detect even the wet hands very precisely. all specs are good really nice product in this range.
#
# 33--> The laptop works very smoothly, the dual fan cooling keeps it cool for a longer amount of time. The display is very shapr and streaming hd/uhd videos is really fun. I haven't had the chance to tryout any games though.
#
# 34--> I have used for 2 weeks and still now I am happy with the product. Only drawback I felt was RAM is 4GB x 2 and it support maximum of 16GB of RAM
#
# 35--> Thank for amazon great indian sell
# I got this laptop with 10% discount
# Dell is the brand that you can trust
#
# 36--> Very much disappointed. I just received this laptop 1 day before and facing so many issues like 100% battery drains out to 0 within 1 hour, keypad and touchpad gets over heated and the keypad is not so responsive.
#
# 37--> the laptop i have purchased is totally waste of money ..the battery is not working properly from the day one .....'
#
# 38--> This laptop battery life is very less and now the display is not opening . The laptop is overheating.
#
# 39--> Amazon cheated customer by promising windows 10 and MS office and asking to buy again same product for same price without software. Cheating customers during sales. don't buy with Amazon.
#
# 40--> Great In Performance Fast Boot Up Excellent Display Value For Money..
# Battery Life Is Ok .. But The Beast Runs So Smooth…
#
# 41--> Battery life is average, not good not bad. It can run for 5 hrs easily if you watch videos online. Laptop is slim. Value for money product.
#
# 42-->  The screen started flickering on the very fifth day of delivery.. very disappointed
#
# 43--> Battery drain very fast. 15 minutes before it was showing 2 hr 50 minutes, after 15 minutes 40 minutes
#
# 44--> Great Gaming Laptop
#
# 45--> NOT GOOD
#
# 46--> Speaker 🔊 get damage in one month only
#
# 47--> Hinge is very bad. Atarts creaking in 10 days. Build quality really poor
#
# 48--> It's a great laptop for everyday use and light gaming. It's super fast.a really good experience
#
# 49--> Screen bleeding issues even after replacement better don’t buy this one but spending above 70k
#
# 50--> luv the laptop..but the delivery service poor..and thy are so rude
#
# 51--> Value for money
#
# 52--> Good
#
# 53--> Nothing to say.. I am mesmerized by this beauty
#
# 54--> Look & Performance both are good... smooth working... stylish…
#
# 55--> Satisfactory product
#
# 56--> Good product
#
# 57--> Battery life is less.
#
# 58--> Keyboard heating problem.
#
# 59--> Great Laptop!!!
#
# 60--> Backlit color should be white
#
# 61--> Awesome product
#
# 62--> Value for money
#
# 63--> Excellent.
#
# 64--> Superb
#
# 65--> Don't think that A Powerful GPU can improve your PC's performance. Even GPU's possess limitations and while testing rigs, I found Nvidia GPU coupled with Intel 10th gen Processor provides more performance(x10) than the Ryzen counterpart. So you need to buy the best processor to get the maximum performance as most programmes are CPU dependent(including Games).
#
# 66--> I purchased the base varient of Dell G3 3500 i5 10th gen from the Dell Showroom in Bilaspur City (C.G.).
# I am using this laptop for about 2 months and here is my review for this laptop.
#
# So here I will tell you I how end up purchasing this laptop even according to many techies this laptop is considered to be overpriced as compared to other laptop.
#
# My first priority was service and according to my past experience with my old dell laptop it was good , my old dell N5050 laptop is running very well even after 8+ years, so I trusted Dell again, Acer and Asus is also giving the better value for money laptop with less malfunction rate but their service as compared to Dell is not so good according to the reviews on YouTube , Amazon and other sources.
#
# Some FAQs regarding this laptop
#
# 1. How is the design and build??
# Ans. This is area where I was very much tensed because of the hinge fail issue which occurred in its predecessor model Dell G3 3590 but in this laptop for using about 2 months no problem regarding hinge occurs at all, its design is completely plastic but of very good quality with very less flex from top and keyboard, its USB ports are hard at first use but later on its get better, vents are given at back and bottom with mesh.
#
# 2. How is the performance ??
# Ans. Its performance is great with i5 10th gen and GTX 1650 and you will never face any lag in normal usage all thanks to the NVME SSD provided which is pcie 3.0 x 2 means only 2 lanes for Read and write (Don't get deep it's very much faster), video editing such as Premiere pro works without lags when applying any filter or when rendering , coding such as Android studio(high CPU demanding),Visual Studio works flawlessly ,I really don't play any games but according to the youtube and review it will able to give about 50 fps average for every AAA titles games at medium settings.
#
# 3. What is the specs of this laptop ??
# Ans. This laptop is having 8 GB RAM but installed as two modules of 4 GB each dual channel but for upgrade purpose to 16 GB you need to remove both RAM modules for dual channeling , don't add 4 + 8 GB RAM as it will not support dual channeling only same GB and same kit support dual channeling.
# Battery is 51 Whr , rest specs is given in dell website or in Amazon.
#
# 4. Ports and battery backup in dell g3 3500?
# Ans. In my laptop the ports were 1x USB 3.2 GEN 1 (5 Gbps) max 500 Megabytes / sec.,
# 2 USB 2.0 ports (60 MBps ), I was bit disappointed as in my varient there is no USB type - C port given but still USB 3.1 does the job for me, 1 x HDMI,1 x Ethernet port but don't know how to insert the Ethernet cable😁,1x 3 in 1 SD card slot,1x audio jack for input and output of audio.
#
# Battery backup is best which I like the most it gives about 6+ hours for normal usage and 3 hours for rendering or coding as compared to ASUS vivobook gaming which is only 42 Whr and in mine lappy it's 51 Whr so you can compare it , even in ASUS vivobook gaming battery backup is even less then to my old dell N5050 laptop having 48 Whr battery, for gaming it will able to give 2 hour battery but it's recommended to play games with laptop plugged in to get better gaming experience and to get better fps as CPU and GPU gets its full power when laptop is plugged in.
#
# 5. Display quality and features??
# Ans. As compared to my old laptop ofcourse the display looks better to me without any screen bleeding or any other issue but going with specs the display is 120Hz , 250 nits brightness (In sunlight the display brightness need to be full ) display having 45% NTSC(Actual colour reproduction capacity when viewed from other display) having much less bezels , 80 % RGB.
# At first start the display looks yellowish due to Eco display feature in BIOS which is enabled by default, turn it off in BIOS for better viewing.
#
# 6. Thermals ??
# Ans. Thermals is decent it is having two fan for CPU and GPU each, for normal usage you doesn't feels any heating issue , for gaming yes the temp reaches to 90+ after 45 min. gaming but after G button temps goes between 80 to 90 without any thermal throttling (CPU and GPU limits its power when temp rises too high is thermal throttling), with cooling pad the laptop temps will remain below the 90+ (so for intense gamer it's recommended to buy the cooling pad).
#
# 7. Camera and sound quality??
# Ans. Camera is 720p resolution which looks better in proper lighting conditions but in dim or poor lighting conditions the camera suffers as it has no flash but for video call, and recording purpose it's better and I am happy with its camera, sound quality for me is great as compared to my old laptop its louder and deeper having no heavy bass.
#
# 8. Other features given?
# Ans. This laptop is having a fingerprint scanner which works flawlessly, inbuilt in power button.
# This laptop also support the auto on lid feature means when opening the lid the laptop starts automatically without pressing the power button although you can turn off this feature in BIOS setup.
# The keyboard is backlight keyboard but having only blue light no RGB lighting like ASUS tuf gaming or any other gaming laptop.
# The charger provided is 130 watt but when charging it uses 50 watt power when seen from HWINFO software, battery gets charged from 8 to 100 percent in about 2 : 30 hours.
# This laptop feature a new button called G (Gaming) for high performance so while playing games do press the G button as it will run the fans at max rpm to give the best performance from CPU and GPU without much thermal throttling.
#
# 9. Some cons of this laptop?
# Ans. In my varient there is no Type - C port given so it's disappointed for me, thermals as compared to ASUS rog or acer predators is not that great but still decent ,yaa you can say it's overpriced but dell support is good, proper button for trackpad should be given(personal con only).
#
# Note : Before using the laptop for general purpose do update the necessary drivers from Dell update website including BIOS, graphic driver, sound driver etc.
# You may encountered some BSOD(Blue screen of death) when installing some drivers , in my case when I was updating sound driver I encountered BSOD which I resolve by updating the driver in safe mode, so it's recommended to install the drivers in SAFE MODE not in regular mode, but if the problem doesn't get resolved yet do get assistance from Dell , but don't reinstall the windows again as it will not going to resolve the problem and installing other windows might void your warranty.
# Attention :
# When updating the BIOS do keep the laptop plugged in and keep battery at 30% and more as it is the most critical update which unfortunately goes wrong can kill your laptop although a back up of BIOS is present in external storage but still be precise regarding the BIOS update.
# Do extend the warranty of the laptop within 10 days of purchase from their respective website to get better support for long years.
#
# The warranty provided is premium support ie 24x7 support through call and chats.
#
# 67--> Guys if you are looking for a budget gaming PC, I would recommend Dell G3 3500 series.
#
# Cost : 70k
#
# I just bought this and I was able to play most AAA titles with decent FPS.
#
# Pros :
# • Dota runs buttery smooth on high performance.
# • Battery backup 6 hours
# • Alienware Command Center is just awesome!
# • One button press boost is the best thing in this.
# • 120Hz refresh rate.
# • Fingerprint sensor.
#
# Cons :
# • Camera module is below average.
# • Available RAM is 8GB which is quite less, an upgrade of 16GB should be done.
#
# 68--> I have purchased 120 hz model
# Nice laptop with nice specifications
# I have purchased it offiline because i got various complimentary things
# I recommend to buy it offline
#
# 69--> I just bought this G3 Laptop paying Rs. 75,000/- from a Dell store in Mumbai. The one star is for Dell's customer service & the Dell store in resolving the issue & not for the laptop. It came with a catalogue which mentions 2 usb C type Gen 2 ports which makes it futureproof for a few years & the product I got was without them.
# I raised this issue with the Dell store & he was clearly not interested in taking up the issue after selling it & asked me to sort it out with Dell . I was taking to the Dell technical people for more than a day.
#
# They themselves admitted it is a mistake but cannot replace the laptop & give me the one with the USB C type ports. So no convincing answer from Dell for this product discrepancy.
# Pls note, this product for the same price comes in 2 variants 1) With a Nvidia 1650 4 GB graphics card & without the 2 usb C type ports 2) With a Nvidia 1650 Ti with the 2 usb C type gen 2 ports which the Dell store in Mumbai is also not aware & he came to know later after I pointed that out to him. According to him the usb C type ports are there in the i7 variant which is wrong( Basically misinformation here too apart from what is mentioned in the catalogue). Going for the second variant makes more sense & value for money.
# As a customer feel that I have not got my money's worth what the company officially claims to give.
#
# Coming to the laptop, I have not used it extensively & is from a non gamer's point of view.
#
# 1) I have the eclipse black version & it looks good.
# 2) Bootup & shutdown is fast due to the ssd.
# 3)The display is ok & not bad & cannot be expected to be of a high end one. The angle of view is not that great.
# Refresh rate options are 60 hz & 120 hz.
# 4) Performancewise assuming it will be good as per user reviews but I have not tested it extensively. I will be
# using it for creative content & general purpose.
# 5) Keyboard is decent & has an option to be backlit with 2 brightness settings & also to switch it off.
# 6) Command G key on the keyboard which boosts the performance for gaming & activates the fans for cooling
# which is a good feature.
# 7) Laptop is on the heavier side since it is meant for gaming but still looks sleek & good. In fact for my tastes, I
# don't like laptops with jazzy colours & lights.
# 8) I found the battery also to be okay giving around 5 to 6 hours since I wont be using for gaming. The charging
# rate is also not too slow.
# 9) The USB ports are not smooth to plug in pen drives or other usb devices. They don't go in easily & you have to
# be careful while pluging them in or while removing them.
# 10) Alien command center for gamers.
# 11) Audio is ok & clear. One cannot expect bass from these tiny speakers.
#
# Overall it is a good laptop. But an advise to buyers is to buy from Amazon or directly from the Dell online store depending on the price. Avoid the Dell dealer shops since they would mostly not help if any issue like this pops up. Buy the laptop which has the Nvidia 1650 ti with the extra 2 usb C type ports.
#
# 70--> What u get from this laptop is quality.
# i am a college student and i bought this laptop for college use only , so quality was paramount for me. I talked to many offline sellers & watched many videos of other laptops in this range with same specs . none of them has the built quality of this laptop. All this lenovo legion and asus ROG laptops are built like chinese fragile glass. they have the same specs but they seriously cut cost in the look and feel.
# this is a very minimalistic design which was perfect for me as i wanted power for coding but didnt want anyone to see me with this as GAMER.
# DELL as a brand legit pumps all these cheap brands like lenovo , hp , asus...you can go to any part of the country but u will still find a service center for dell...and their parts are also very cheap
# look...i wont go into the specs and all because there are plenty of reviews and videos about it..BUT i will talk about the real thing that should matter
# at the end of the day if u are spending this much money atleast make sure it lasts long
#
# 71--> I buy this laptop 2 times 1st time I ordered and I receved but after receiving I used for two days after 2 days it is asking for recovery key after typing recovery key also it is not working so I returned it 2nd time also it repeted the same after 2 days so I placed my refund today. I called Amazon service about the problem the said me to call Dell services so I called them they told me they also don't know about that problem so my suggestion to don't buy this product
#
# 72--> I have been using it for a while. I purchased in March. It has a great screen. backlit keyboard is good. only issue is, when you open the screen the heat exhaust directly blows air on the lower part of the screen. This heats the screen. and since it is very much near the hinges, the screen and body joint gets the imapact, In my laptop this part got loose and it opened. finally I got my screen replaced.
# The dell warranty is great and service is awesome.
#
# 73--> Battery life very poor: 3 hours, but can use conservation mode to enable "plugged in, not charging" option.
# Audio: average, not upto the level of Dell or JBL speakers
# Performance: above average or close to excellent
# Stability: above average or close to excellent
# Keypad: Excellent
# Graphics: above average
# Price: below average: bought it for 86k (incl 3yr accidental damage warranty). Lenovo has lower cost laptops with 5000H series at 63k.
# Application interface: Excellent
# Require: Antivirus or Total security from Kaspersky. McAfee is very poor, and should be dropped
# Privacy: Very Poor, Not sure of compliance, privacy issues possible
#
# 74--> The product is good and amazing , dont blame the company , but the supplier and the retailor has done the bad work . The battery life of this laptop is worse and received a default piece . The actual original laptop is very good . Dont buy it from any other online platforms or other retailors . Go to the legit and authorised stores like Dell , Reliance Digital , Croma Mall , Etc. Others local retailors might make us fool by giving default pieces . And whenever you buy a product check it when the retailor breaks the seal pack infront of you and the box labels are not hidden with non transparent stickers or it might be fraud . I was trapped by a CSD dealor means Canteen Stores Department by selling it with the price of 63,556 Rs . And the product started showing error since Day1 even without playing any games or using softwares . The video also lags and shows cracked pixels . Be alert and take a genuine product . Check each and every thing you doubt about while buying . Money is earned by hard work and we can wait their for 1-2 hours for our self satisfaction . Dont hesitate to ask them for every query . And if problem occurs before 15 days of purchasing , immediately show it to the retailor and have a re replacement or refund . Dont just ignore the issue .
#
# 75--> Looking is beautiful. More feedback will be later after use.😄😄😄
# Premium design and good quality of web camera..
# But i think it should be in the range of 45k to 55k
#
# 76--> This is amazing laptop one should really go for it ..... Bit costly though but with cost u will get way better service than other brands .
# Pros : played GTA 5 , destiny2 , apex legend .... working like butter
#
# 77--> One of the top best product of dell i liked very much and i always prefer you to buy this
#
# 78--> The best budget gaming laptop by Dell.
#
# 79--> Great specifications and looks also.
# Gets the job done
#
# 80--> I am using from last 1 month.... till now its working fine... only issue what I felt is battery will drain fast... so I need to keep charging frequently.
#
# 81--> Heat vent opening directs all inside hot air towards laptop screen, which start damaging screen during long continuous ussage. I was not expecting such poor design from Dell.
#
# 82--> Nice laptop
#
# 83--> Nice anti glare and sleek screen
#
# 84--> Nice product and i specially like thin border and design of this laptop and colour is also awesome and value of money…
#
# 85--> Best laptop ever made..Better than Macbook ai r🖕🖕,but not as good as msi gl65 leopard(RGB) 8gb, 4gb graphics card
# (Sidechick)
#
# 86--> Best laptop dell inspiron 3501,core i5 11 gen,8 gb ram very fast laptop nice product, coding,photo edit and student user best laptop. Battery backup 5,6 hours . Dell laptops much better than Asus and Lenovo laptop.
#
# 87--> I REALLY LIKED IT AWESOME,BOOTING TIME IS VERY FAST AND 11TH GEN IS SUPER . THE RAM IS NICE .
#
# 88--> Dell XPS lineup is one of the well known laptop lineup all over world
#
# This model has a few cons:
# 1. Fan kicks in a lot, even when browsing web it will start running. But the fan is definitely quieter than a Macbook Pro 13
# 2. Can get really hot at the base. I am not complaining about this. Its a 13 inch thin and very powerful machine, so you will have to accept that it will heat.
# 3. Has a lot of QC issues. The unit i got had a faulty button coming out of the keyboard. Get the product replaced if you get a defective one. You can read all over the web that people are reporting QA issues
# 4. Windows 10 issues. Brightness issues - You won't be able to set auto brightness off. Brightness will keep changing abruptly while you watch a video. People have reported other windows issue as well. I have installed a Linux Distro in my unit, and thankfully i am not facing any software issue. Working like a charm
#
# Apart from these cons, i don't think there is anything to dislike about this product. I have owned previous xps laptops and have been pretty much satisfied with them. This one brings a significant update to the lineup
#
# Edit:
# The model seems to have a ton of Quality issues. I got my replacement for the first unit, which had a faulty keyboard. Now the new unit's fan does not respond. It does not pass the POST test. Also the hinge is so stiff that the laptop does not close at all and keeps popping open. Really disappointed now. Returning this one as well. They are so beautiful and I desperately want them to work :(
#
# Edit:
# I got the third replacement. Finally it was a unit which does not have any QA issues. Its serving me fine for the last 3 months. Happy now!
#
# 89--> GOOD STUFF:
# Beautiful, sturdy design
# Bezel-free 16:10 display
# Standout keyboard and touchpad
# Integrated graphics can handle some gaming
#
# BAD STUFF:
# Keyboard gets hot under load
# Limited port selection
# Bad webcam
#
# 90--> Laptop has hardware and software issues
#
# 91--> No complaints so far...Fully satisfied…
#
# 92--> Dell XPS is one of the worst laptops in premium segment, i have wasted almost 1.5 lakhs and at the end suffering from heat and already motherboard is failed. Lenovo Carbon X1 is the best alternative.
#
# 93--> Overpriced Product
#
# 94--> Not sure why there are so many negative reviews because this laptop has served me so brilliantly. It is an excellent laptop and has done very well despite the price I had to pay for it
#
# 95--> Product is good, I will recommend if someone wants to buy it.
# - Product was not packaged nicely.
# - AMAZON packaging was loose and bad. It was literally coming out of the packaging.
#
# 96--> showing white image and sending black laptop. Beating and sound quality is soooo poor.
#
# 97--> This is my fav laptop till date. It’s super good looking and light weight.
#
# 98--> lukz geeat performance high.... fully satisfied
#
# 99--> Whare is graphic card atleas 4 GB is mandatory in today world . Sach as high price laptop very disappointed no touch screen no graphic
#
# 100--> Dont buy Dell.. I have a 13.3 inch Dell Inspiron.. latest model .. everything is good except that the battery lasts on 5 mins after 1 yr use.. !!!! I paid INR Rs. 1.1 lacs for that!!!.. what can you do with a laptop if the battery runs out continuously and you are forced to plug in every minute of the day?? And if electricity goes out then god bless you!! For INR Rs. 1.1 lacs I expected much much better.. Dell is only brand value.. rest is NOT VALUE FOR MONEY.. my previous laptop was a Acer Aspire with lasted for 8+ years and used to give atleast 7 hours of battery and atleast 3 hrs in the 8th years also. Compared to that Dell seems very useless wrt battery life. I just looked up the latest Acer Swift 3x which has 17.5 hrs of battery life..
#
# 101--> Very disappointed with Dell XPS.
# Multiple issues - heating, microphone not functioning, frequent shut downs.
# Not at all worth the cost.
#
# 102--> Very Good Performance
#
# 103--> Product price is worth. I am satisfied with the product and its specifications. I would say its a must buy.
#
# 104--> Laptop features are good thats why i bought it but only mistake i made is to buy it from amazon. They sent me an old laptop as u can u see in the pic their screws seems opens and looks refurbished. Very disappointed. Will not buy anything expensive from amazon from now.
#
# 105--> Not the product i ordered for with missing accessories like pen finger print scanner Microsoft Office installation key
#
# 106--> Good
#
# 107--> Laptop is really nice. But the problem is after 1 month of usage started heating. After 30 mins of usage starting heating.
# Apart from everything is good
#
# 108--> bought from offline dell exclusive store:
# Rs 90,000 with 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz with 8GB/512GB (intel iris graphics + 2GB dedicated NVIDIA grapgics) upgraded RAM to 16GB with Rs 4000 Extra..
# In box Pen active stylus + Charger.
#
# 109--> This is a great all around laptop. It's blazing fast with its Intel 11th Gen chip. It is also very light and you can carry it around very easily.
# I've only used it for a couple of hours and the only problem I see is that it is heating up a bit. Again, I'm not going to use it for anything groundbreaking as I'm a student, but it's a factor for some people.
# I'll add more things after a week or two.
#
# 110--> Bought from dell exclusive store in 67500/- however laptop build quality is good and touch is very smooth. Touch pen experience is also good. Overall for online tutors its a great product.
#
# 111--> Good design, Very fast booting and lightweight, best battery backup to 5 hrs, fast finger sensor access the open the window, automatic system ON when the laptop open
#
# 112--> I bought this laptop from Dell exclusive store and it getting heating from day 1 with noisy fan sound,.
# I took dell support assist but still problem didn't get solved
#
# 113--> Good laptop with great specs ,web cam is also good ,battery backup 4-5hrs btw ,light weight ,and also good for gaming,finger print sensor works well
#
# 114--> Nice laptop in this price in one problem in this laptop HDD is not available but other thing is good
#
# 115--> A good laptop. Looks very sleek and lightweight. Has an aluminium body. Performance wise also good.
#
# Made in China though. No power on indicator, need to make out if the laptop switched on by the backlit keyboard.
#
# Had an issue of laptop not switching on after going to sleep but that was resolved after a firmware update.
#
# 116--> I was quite nervous to buy this laptop considering someone mentioned regarding Coil Noises. But I took the risk coz I literally couldn't find any laptop with this specs at this price range.
# I basically bought this laptop for Coding/Media and multitasking and to be honest , it works perfectly.
#
# Pros:
# 1) Low Noise after upgrading drivers
# 2) Multitasking/Coding No issues
# 3) Display is really Good
# 4) Can Play Basic to Midrange Games
# 5) Elegant design
# 6) Mcafee for 15 months / Windows 10 and MS 365 lifetime
# 7) Can upgrade your RAM upto 32 GB if needed
# 8)Quality looks top notch
# 9) Charging 80 percent of the battery in 30 mins is something I really needed
#
# Cons:
# 1) Tends to Heat up if you are running applications that require high processes
# 2) Battery life is about Average
# 3) Keyboard is too soft. Some may like it and some may not. I don't
#
# 117--> The laptop gets overheated within 10-15 mins of use, there are multiple glitches, and the laptop freezes every time you open more than 3 tabs at the same time. The audio drivers were not working even after several windows and driver updates. The heating issue is damn serious and annoying, especially at the keyboard and bottom part of the body.
#
# I would not recommend purchasing this because the tech support was denying all the claims made against the problems associated with the laptop, and even amazon was manipulating and facts and refused to give a refund/replacement. Purchasing this product on the basis of the description and its design was the biggest mistake I ever made, and this transaction has made me lose my faith in doing any future purchases from amazon. The technician was denying all the issues and was suggesting me to take the laptop to the Dell service center and get the errors rectified, which is not my job and shouldn't be happening with a brand new laptop in the first place
#
# At last, I would not recommend purchasing this model, because it is poorly built and if you face any issues, amazon's team will not help you resolve them and you will be the one suffering loss and end up owning a faulty and defective laptop.
#
# 118--> A defective model plzz don't buy it, I have replaced it twice due to defective products and atlast I chose to go with refund.
#
# 119--> Packaged well and received in good condition..
#
# Unfortunately things looks bitter after the setup..
#
# 1. Freezing a lot.. When opened a browser..🙆‍♂️🙆‍♂️🙆‍♂️
#
# 2. Overheating, literally after 10 - 15 minutes of usage the heat raised like I'm placing my fingers in oven..🔥🔥
#
# 3. Most importantly the battery percentage is not going up, even after charging for couple of hours.. 🙄🙄🙄
#
# 4. Finally the USB ports mentioned in the description is not matched with the product, as they mentioned 3 ports in the description but there are only 2..🤦‍♂️🤦‍♂️🤦‍♂️
#
# Returned the product today.. 🙏🙏🙏
#
# Overall, I can say that this is a disappointing product from dell..
#
# 120--> This laptop like many other Dell laptops (including the XPS models) has COIL WHINE issue. Coil whine is a buzzing electrical sound only audible when bring the laptop close to your ear. In this laptop it's audible in the top left corner.
# I ordered a replacement and the replaced laptop has the same issue out of the box.
# Coil whine can be reduced if you tinker with the graphics driver settings (or even uninstalling or upgrading/downgrading as that has shown to solve this issue) but sadly these fixes don't seem to work for my laptop.
# Coil whines are not dangerous/it won't damage anything. It's just annoying when you are sensitive to it.
# Other than this, this is a good laptop.
#
# 121--> The laptop is very well built and meets the need of any average user. It comes with excellent display, quality build metal chassi (back is polycarbonate). Gives great looks while using, expandle memory till 32gb, cpu does not break sweat on heavy tasks, operates silently most of the times. A tiny coin while sound is heard from bottom of laptop that should not impact the user experience or machine performance. It's great price and steal deal to buy within 70k. Looks are amazing, the typing experience is very good keys are noiseless.. the backlight on keypad could have been improved like HP's but it's okay. Sound is powered by wavemax pro and really should fulfill entertainment needs while watching movie or songs. The hinge feels sturdy and no flex found the port selection is very good and covers basic needs like Hdmi 1.4, usb type-c power delivery and data transfer. The finger print sensors needs some improvement but works well over the time. The fast charge of 65w is disabled by default, go to bios settings and enable fast charging and you would get this charged very fast. Once the updates are ran the laptop operates cool and no issues noticed. The display is great to look at viewing angles are awesome, no colour shift noticed like tf panels. This display matches the IPS level of display experience. The browser and other apps really render the fonts very well and no pixelation noticed, good for coders and high resolution admirers. Okay, anybody want to get good sturdy laptop for coming years then this is it. Dell has really manged well to provide handy apps to take care of entertainment with dell cinema and decent audio which are highly configurable. Go for it, you won't regret.
#
# 122-->  this laptop delivered on 23rd oct..then i use this laptop many issues found.
# 1. Display Blinking Automatically (see video)
# 2. Display Colour Change and All display show green Colour.
# 3. Heating Issues.
# 4. If Increasing Full Sound then Speaker not gave Proper Sound.
# 5. Fan Sound is more Loud compare to others laptop.
#
# 123--> I have been using my office Business Dell laptop Latitude 7300 and when I have started using this Inspiron 5408, it feels the same comfort and high end feel with it's overall ergonomic design and aesthetics.
# Well built, sturdy and reliable laptop which uniquely gives an extra capacity up to 32Gb RAM.
# With same price tag, I didn't find any other laptops providing you with extended RAM capacity.
# I would like to highly recommend this laptop as this gets me the same feeling as that of my Dell Latitude Business laptop. Thank you Amazon for exchange value and ease of delivery partnership provided. Special thanks to Dell as well for changing their design language into an youth orientated Ultrabook. Cheers. Peace!!!
#
# 124--> The laptop had loud fan noise initially. But after the drivers update it has come down.
#
# There is a bit of coil whine. But will hear only if you place your ear close to keyboard. It is there in every laptop but this one is but audible at close distance.
#
# ...
#
# 419-->  Defective product. Restarting again and again. So much money wasted.
#
# 420--> A beautiful laptop with amazing performance and good battery life. Despite being part of Dell's mid-range inspiron series, it has a premium design so you don't really miss out on that experience.
# Checks almost all the essential boxes. Its compact form and light weightedness makes it suitable for outdoor use and travellers. Reviewing almost a month after purchase. It has got some negative reviews, but honestly I didn't face any of the reviewers mentioned problems. Although.. there were some pre-installed app realted issues but they were quickly resolved by Dell Tech Support. They(Dell) were quite prompt in helping the customer. One less star for small touchpad, also I wish the keyboard were black instead of silver, would have made it stand out. Overall a decent purchase.
#
# 421--> Product works smoothly, thanks to windows 10. BUT ABSOLUTELY HORRIBLE PAINTJOB BY DELL. Paint is chipping off everywhere, without any moisture/damage (the laptop has been at the same spot for past 3 months, never gone out). Didnt expect such a poor build from Dell.
#
# 422--> I'm not sure if this is an Amazon problem.
# But leaving this review here as there is a massive product defect in the Inspiron 14 7490. DO NOT BUY THIS SPECIFIC MODEL.
# Within 3 months, the hardware, fan belt and cooling has shut down and the engineer opened up the laptop which then has led to motherboard failure.
# And now Dell is saying that they have weird terms & conditions like they will take 60 days for a replacement, with a body/model of any laptop but specifications as current, and no extended warranty on the product.
# They are probably selling refurbished laptops at the price of new ones and duping people massively hence they have such absurd terms & conditions.
# AMAZON, please do complete verification from such mal behaviour and delist these models/ products for now.
#
# 423--> I was so afraid in the beginning because there was fan noise and heating, but after the BIOS update, it is running super cool. Very good machine.
#
# 424--> Pros : Battery life is good, looks is classy, handy..
# Cons : Facing issue only after purchase of 3 months "Hard Drive - Not installed", too costly
#
# 425--> Portability and battery life are just amazing. Little noisy when cpu fan starts but not very bad. Overall very good buy
#
# 426--> Processor is very slow and making loud noise starting from day 1. Not worth for money
#
# 427--> Amazing product
#
# 428--> Satisfied
#
# 429--> Laptop is not working within one week
#
# 430--> It got this laptop from office for work. The laptop is light weight, screen resolution is good and the keyboard gives good tactile feedback. It’s a excellent laptop for work.
#
# 431--> Laptop as described. For longevity and ROI - go for Dell. no concerns so far.
#
# I'm not a gamer but wanted a laptop with good config, 15.6 screen, core i5 and 8 gm ram. Most laptops in this config are gaming laptops.
#
# Great performance, display and build quality. In love with the keyboard. A little bit on the heavier side - if you want lighter laptops, go for the 14 inch ones.
#
# Will update my review in a month's time with additional Pro's and Con's.
#
# 432--> Wonderful purchase, exceptional sound output, starts in less than 10-15 seconds, with right settings you can start and shutdown this laptop with swing of lid, smooth gaming experience, 4 hour battery backup if chosen correct settings, in short Alienware for poor people
#
# 433--> Superb PC must buy
#
# 434--> Bad Experience for Hardware
#
# 435--> There is some noise near hinge when you close or open the lid .
#
# 436--> Overall performance is good but gets heat up quickly. The cooling system is best but air outlet is infront of display so screen also gets heated. A error occurred while gaming like it took exit unexpectedly
#
# 437--> I am giving this feedback cause for no solution for my replacement of damaged charger and battery backup is very low
#
# 438--> Beast at this price . Purchased at 54k
#
# 439--> Before buy check the battery condition.
# 3 cell r 6 cell r 9 cell
# You need more power backup choose 9cell.
#
# 1hour stand by time on 2.30hr charged
#
# Don't buy my humble request
#
# 440--> If Keyboard light must have an option for white light.
# Type C thunderbolt port missing.
# At least minimum 2 usb 3.2.
# Webcam shutter.
#
# If these things are provided then this laptop become a must have laptop for medium families.
#
# But in this price range this a super performer.
#
# 441--> im using it about 2 months very nice
#
# 442--> Awesome..super fast...little battery issue..
#
# 443--> Working Super
#
# 444--> Awesome product.
# Only bad is the battery 🔋backup.
# Otherwise awesome.
# Great screen quality
#
# 445--> 1)laptop screen bleeds at corners
# 2) consumes more Ram when being idle
# 3)and at this price range we should get at-least 2400Mhz of ram not 1600Mhz.
#
# 446--> Device is good but the price(66k) I bought it is out of the world..
#
# 447--> Ultimate performance super laptop
#
# 448--> Still have to see but very happy with the product
#
# 449--> Powerpack laptop , best in class ,
#
# 450--> The antiglare screen is really really awesome!
# Boots up in less than 8 seconds.
# G mode is really handy and the alienware command centre is simply amazing and the app u would use the most !
# Only 1 thing which u can think on is that it is a little on the heavier side .although the dimensions are compact
#
# 451--> Good product nicely delivered and good packing.
# 4-5 hrs on battery if using in normal mode
# On gaming 2-3 hrs of battery life.
#
# 452--> Perfection for a top of the line company. Only issue is the overweight.
#
# 453--> Great Product.
#
# 454--> One of the best gaming laptop in this price range
#
# 455--> performance is good, but the overall design and body is poor
#
# 456--> Power button has to press several times to switch on laptop when not connected to charger
#
# 457--> This product is good, didn't observe much of heating issue while using gives around (4 and half -5)hrs of battery back-up can be even more if you r a normal user however face sign-in is still not available in this device may require an update waiting for it .
#
# 458--> There is no ms office 2019 in this product they are giving office 365 one month free which you get free without buying any product from microsoft website as well. so please take a note and dont buy it for MS office .... 5200 Direct loss.
#
# 459--> The mouse bbuttonn cann be pressed from under the laptop. also as you can see the keyboard does doubletying for certain buttons annd sometimes keys like space, numbber 2, n annd b does not work on the first press.
#
# 460--> We were given a refurbished laptop. After a ton of escalation to Dell, got it replaced.
#
# 461--> its awesome
#
# 462--> Good product, price is high on this ecommerce site. On store it is 59k.
#
# 463--> Really a good product.
# Anti glare screen. There are lots of small thing example dell connect dell charging and so on which comes really very handy.
# Body is made up premium plastic.
# Fast changing
# And most important thing very reliable and its stores are easily accessible in case you need any help.
#
# 464--> Worst ever Model from dell totally disappointed. I'm just a developer and programmer i just use to code and run avms but it heats and and it can fry an egg with its heat idk why they launched such a worst product with out proper cooling system.
#
# 465--> The keypad doesn’t work properly, on the excuse of Covid service to attend takes time but the customer complaint is not attended placed in a similar situation.
#
# 466--> Received 1 day before the delivery date. But the recieved item has a scratch on metal body
#
# 467--> Everything is nice about this product as mentioned. Just the backlit, having it or not doesn't matter. Very low. Only con there I realize.
# No heating issue for me,
# I don't watch movie or play games so no idea about the graphics.
# Overall I loved it, even my cousin was astonished saying that he didn't had any idea Dell Laptops could be this eye catching... 🤭... And for me screen size is great!
#
# 468--> Its an amazing experience to work on this laptop. its been 3-4months of intensive usage as i am a research student. The softwares have been running extremely smoothly and the boot is very fast! it has touch id, backlit, ssd almost all the features i was looking for!
#
# 469--> First Of All, I am writing this review after using this laptop 1 month and trust me this is an awesome laptop .
# Also, I have read one review from a person who had ordered this laptop and was facing problem with audio jack. So, to that person and all of you I want to say that audio jack is in completely good condition you just need to update some drivers then it will works well.
#
# Now,
# Display- its display is just amazing and colours are very vibrant and punchy.
#
# Keyboard- Its keyboard is very soft and smooth also I found it better than my 2017 model macbook air.
#
# Performance- It is indeed a very fast laptop and for coding, website developing, designing work and for other day to day work.
#
# Overall, it is just just awesome laptop and also I found it slightly better than my Macbook Air
# Just Go For It.
#
# 470--> Audio jack is not working. Recieved defective product. And no option for replacement. Dell assured me that product need to be replaced but flipkart is not replacing the product and keeps on postponing the date of replacement.
# Horrible experience of buying laptop from flipkart.
# It's been more than 18 days and flipkart is keeping on expanding the date of replacement. Terrible customer support and worst experience.
#
# 471--> Pros:
# Thin and light weight
# Display
# Fast performance
# Cons:
# Keyboard size
# Sometimes screen is fluttering
# Sound is bit low
#
# 472--> This is my initial review. It's really volue for money product. One touch unlock is precise. Light weight. And backlit keyboard. Good for personal use.I will give final review after some time.
#
# 473--> It looks perfectly fine, I ordered it on 30 Oct and received it on Nov 1.
# It's working fine
#
# 474--> Normal office, college and school work, social media, entertainment etc goo for it.
# Good camera, speaker, battery life, design, body, etc modern ports. The best you can get in this price range.
#
# 475--> Very good
#
# Trust of dell is main thing for which I bought this one.
#
# As thought, This is up to mark.
#
# If you are looking for online classes, then buy 39 cm one
#
# This is more for people who are on move.
#
# No cons so far.
#
# 476--> Product is very good. But not loo lightweight and not so thin ..
#
# 477--> Battery back up not satisfied and
#
# 478--> Speed of laptop is good and I could use Matlab & Python at the same time.
# But some times it's taking some time to turn on after pressing power button.
#
# 479--> After I charge the laptop for 30 mins , it was heated like fire. Never expected such a product from dell. Laptop is for lap. So i it heats up while charging you can't put it on your lap and the reason for getting a laptop is lost there only.
#
# 480--> Slim n sleek design.... performance is good, display n spekaers are better than the other in this range
#
# 481--> Using from last one month. So far so good . No issue . Battery is good enough. Performance is excellent. Awsome look
#
# 482--> Good laptop ,batter backup is good ,screen quality,sound is best ,figer print scanner ,backlit keyboard works perfect.
#
# 483--> I have experienced a problem while connecting to headset. Otherwise it is a worth product
#
# 484--> Great product.
#
# 485--> Elegant by looks
# Smooth in operating
# Happy till now
#
# 486--> I did research on laptops for past 2 weeks and finally made the decision of getting myself Dell Inspiron 5408 series. Let's start with each points.
#
# Looks : Premium design, diamond cut hand rest which gives it a classy finish. The backside is quite similar to the mac air which is also good.
#
# Performance: I use them for content typing, editing, presentations, online conferences, mostly all of these at the same time. So, multi-tasking really works well with the i5 processor. The camera quality is well enough for meetings. Also, some light games like asphalt, nfs, cod works well and the display is really awesome for games and videos.
#
# Overall, the specs, the looks, performance at this budget is a deal. And yes there are other laptops with the same specs, probably higher at the same rate. But the build quality and the premium finish of this laptop is top notch.
#
# 487--> Delivery experience was great ......and product is awesome....looking cute luxury....and power house in terms of technical
#
# 488--> flipkart Delivered laptop to me on 7th Nov 2020 - Saturday evening
# Initially laptop had major startup and hanging problems for first 4 days.
# Contacted DEL support and DEL hardware engineer updated all the drivers , even though Issues of laptop wasn't fixed.
# After making lot of noise with DEL, DEL hardware engineer done some major Bios Updates(may be properly done hardware updates) & OS updates.
# After that from last 2 days laptop is working perfect . So far no issues.
# 5408 is good looking ,slim , light weight & high performance laptop. if it continue perform same for next 1 week , I will give 4 or 5 ratings.
# will continue to do thorough testing on all features and update the posting and revise rating in 1 week. So far working very good.
#
# 489--> Very good product in 60k range
#
# 490--> Slim and Portable laptop. The spec is amazing at this price range(59K) and the build quality is superb.
#
# 491--> All as described. Finally a speedy experience at a nominal price. Also the keypad is very soft. Really works wonder with typing. Battery backup is average. Light weight so can work for long hrs. With i5, the speed is awesome. Loving it so far.
#
# 492--> Very Nice Product.
# Battery and Performance is also great.
# Value for Money.
# Premium Sleek Design.
#
# 493--> Just one word ...wow
# Amazing laptop. I wanted this for my personal use...it definitmeets my expectation....i got it at a cheaper rate in the sale....again the price has gone up....overall a very good deal. Really happy. Feels premium when you hold it…
#
# 494--> Very premium finish
# Display is awesome
# I have used it for one week.
# On general use battery lasted 6-7 hrs
# I felt the key travel is not good enough.
# Rest all is god
#
# 495--> There is no MS home and office included in the product and it is generally free with dell laptops. Further, it is mentioned in the description as well. All you get is 30 day trial subscription to MS Office 365! Called Dell support and they mentioned it is not included with the laptop. Bad experience.
#
# 496--> In product descriptiom SSD drive was included but it was not part of the laptop configuration
#
# 497--> This product doesn’t have MS office. When I contacted the amazon customer care about this they are saying that this product will be having either with MS office or Intel graphics. They came to this conclusion because it was mentioned “/“ in between MS office and intel graphics in the title of the product. See how these People are making false statements to coverup their mistakes. It was basic thing that maximum all dell laptops are provided with intel graphics.
# In that case 8gb /512gb ssd was mentioned in the title of the product, so the product will come with either 8gb or 512gb??? No right, then how can u make statements like that , It will be provided with either MS office or intel graphics?
#
# 498--> Has a premium look , sleek and fast processing.
#
# 499--> Bought this laptop on 6th August 2020, delivered on 10th August 2020. When I checked the warranty, it says will expire on 22nd October 2020.
# As per the initial terms and conditions a warranty of 1 year was included with this purchase.
# Would request amazon to look into this urgently.

# %%
dfL = pd.read_csv('/Users/Akashgupta/Desktop/NEWERFIN/disser/GOLD_LABELS_len.csv')

# %%
df['LENOVO']
# Out:
# 0      Very slow processor, very very laggy... This l...
# 1      It is total waste laptop. In fact its not a la...
# 2                                          It's awesome
# 3      strongly recommend not buying laptops from Ama...
# 4      i think they are trying to pass out defective ...
#                              ...
# 494    worst . very slow , and within six months keyb...
# 495    Looking very nice but working performance is v...
# 496                               Processor is very slow
# 497    Very bad laptop.. too much slow performance. S...
# 498                        Light weight and good product
# Name: LENOVO, Length: 499, dtype: object

# %%
df['LABELS'] = dfL['LABELS']

# %%
df
# Out:
#                                                 LENOVO  LABELS
# 0    Very slow processor, very very laggy... This l...       0
# 1    It is total waste laptop. In fact its not a la...       0
# 2                                        It's awesome        1
# 3    strongly recommend not buying laptops from Ama...       0
# 4    i think they are trying to pass out defective ...       0
# ..                                                 ...     ...
# 494  worst . very slow , and within six months keyb...       0
# 495  Looking very nice but working performance is v...       0
# 496                             Processor is very slow       0
# 497  Very bad laptop.. too much slow performance. S...       0
# 498                      Light weight and good product       1
#
# [499 rows x 2 columns]

# %%
dd = {0: 'neg', 1: 'pos'}

# %%
df['LABELS'] = df['LABELS'].map(dd)

# %%
Lenovo = L_stats(df, 'LENOVO')

# %%
DFL = Lenovo.tokenized_no_stops()
reviews_all = []
for i in range(len(df['LABELS'])):
    reviews_all.append((DFL[i], df['LABELS'][i]))

# %%
random.shuffle(reviews_all)

# %%
freq_words = nltk.FreqDist(Lenovo.vocab_no_stops())

# %%
word_features = list(freq_words)

# %%
def review_features(review, w_feat):
    review_words = set(review)
    features = {}
    for word in w_feat:
        features['contains({})'.format(word)] = (word in review_words)
    return features

# %%
feature_sets = [(review_features(r, word_features), c) for (r, c) in reviews_all]

# %%
train_set, test_set = feature_sets[:350], feature_sets[350:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.8389261744966443

# %%
classifier.show_most_informative_features(50)
# Out:
# Most Informative Features
#           contains(best) = True              pos : neg    =     24.6 : 1.0
#          contains(value) = True              pos : neg    =     15.2 : 1.0
#          contains(great) = True              pos : neg    =     14.1 : 1.0
#          contains(worst) = True              neg : pos    =      9.6 : 1.0
#            contains(bit) = True              pos : neg    =      8.9 : 1.0
#           contains(nice) = True              pos : neg    =      8.7 : 1.0
#          contains(waste) = True              neg : pos    =      7.9 : 1.0
#           contains(ever) = True              neg : pos    =      7.4 : 1.0
#          contains(price) = True              pos : neg    =      7.0 : 1.0
#         contains(return) = True              neg : pos    =      7.0 : 1.0
#        contains(awesome) = True              pos : neg    =      6.8 : 1.0
#           contains(slim) = True              pos : neg    =      6.8 : 1.0
#         contains(budget) = True              pos : neg    =      6.6 : 1.0
#         contains(normal) = True              pos : neg    =      6.0 : 1.0
#      contains(purchased) = True              neg : pos    =      5.7 : 1.0
#          contains(month) = True              neg : pos    =      5.3 : 1.0
#          contains(takes) = True              neg : pos    =      5.2 : 1.0
#         contains(gaming) = True              pos : neg    =      4.9 : 1.0
#           contains(open) = True              neg : pos    =      4.9 : 1.0
#       contains(purchase) = True              neg : pos    =      4.9 : 1.0
#           contains(take) = True              neg : pos    =      4.9 : 1.0
#      contains(excellent) = True              pos : neg    =      4.7 : 1.0
#           contains(home) = True              pos : neg    =      4.7 : 1.0
#          contains(needs) = True              pos : neg    =      4.7 : 1.0
#          contains(range) = True              pos : neg    =      4.7 : 1.0
#         contains(useful) = True              pos : neg    =      4.7 : 1.0
#            contains(use) = True              pos : neg    =      4.6 : 1.0
#           contains(days) = True              neg : pos    =      4.5 : 1.0
#   contains(disappointed) = True              neg : pos    =      4.5 : 1.0
#           contains(slow) = True              neg : pos    =      4.3 : 1.0
#        contains(classes) = True              pos : neg    =      4.3 : 1.0
#           contains(even) = True              neg : pos    =      4.1 : 1.0
#       contains(warranty) = True              neg : pos    =      4.0 : 1.0
#         contains(design) = True              pos : neg    =      4.0 : 1.0
#        contains(service) = True              neg : pos    =      4.0 : 1.0
#           contains(fast) = True              pos : neg    =      3.8 : 1.0
#       contains(keyboard) = True              neg : pos    =      3.7 : 1.0
#            contains(1tb) = True              pos : neg    =      3.7 : 1.0
#            contains(45k) = True              pos : neg    =      3.7 : 1.0
#         contains(advice) = True              pos : neg    =      3.7 : 1.0
#       contains(expected) = True              pos : neg    =      3.7 : 1.0
#           contains(guys) = True              pos : neg    =      3.7 : 1.0
#         contains(mobile) = True              pos : neg    =      3.7 : 1.0
#         contains(movies) = True              pos : neg    =      3.7 : 1.0
#        contains(playing) = True              pos : neg    =      3.7 : 1.0
#          contains(study) = True              pos : neg    =      3.7 : 1.0
#       contains(suitable) = True              pos : neg    =      3.7 : 1.0
#           contains(word) = True              pos : neg    =      3.7 : 1.0
#            contains(bad) = True              neg : pos    =      3.6 : 1.0
#           contains(boot) = True              neg : pos    =      3.6 : 1.0
